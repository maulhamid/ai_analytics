# %%
from langchain.prompts import PromptTemplate, FewShotPromptTemplate
from langchain.chat_models import ChatOpenAI
from pydantic import BaseModel, ValidationError
from typing import Optional
import pandas as pd
import re
import time
import openai
import os

# %%
import pandas as pd

survey_result = pd.read_csv("survey_self_tracking.csv")

examples = []

for _, row in survey_result.iterrows():
    example_dict = {
        "Nama": row["Nama"],
        "Usia": row["Usia"],
        "Jenis_Kelamin": row["Jenis Kelamin"],
        "Asal": row["Asal"],
        "Penggunaan_Alat_Pelacak": row["Penggunaan Alat Pelacak"],
        "Jenis_Alat_Pelacak": row["Jenis Alat Pelacak"],
        "Motivasi_Real_Time_Data": row["Motivasi Real-Time Data (1-5)"],
        "Bandingkan_di_Media_Sosial": row["Bandingkan di Media Sosial (1-5)"],
        "Bantu_Konsistensi": row["Bantu Konsistensi (1-5)"],
        "Rasa_Bersalah_Jika_Tidak_Capai_Target": row["Rasa Bersalah Jika Tidak Capai Target (1-5)"],
        "Meningkatkan_Pola_Hidup": row["Meningkatkan Pola Hidup (1-5)"],
        "Menetapkan_Target_dari_Data": row["Menetapkan Target dari Data (1-5)"],
        "Manfaat_Terbesar": row["Manfaat Terbesar"],
        "Tantangan_Kekhawatiran": row["Tantangan atau Kekhawatiran"],
        "Fitur_Baru_Diinginkan": row["Fitur Baru yang Diinginkan"]
    }

    formatted_string = ', '.join([f"{k}: {v}" for k, v in example_dict.items()])
    examples.append({"example": formatted_string})

# %%
class SelfTrackingSurvey(BaseModel):
    Nama: str
    Usia: int
    Jenis_Kelamin: str
    Asal: str
    Penggunaan_Alat_Pelacak: str
    Jenis_Alat_Pelacak: str
    Motivasi_Real_Time_Data: int
    Bandingkan_di_Media_Sosial: int
    Bantu_Konsistensi: int
    Rasa_Bersalah_Jika_Tidak_Capai_Target: int
    Meningkatkan_Pola_Hidup: int
    Menetapkan_Target_dari_Data: int
    Manfaat_Terbesar: Optional[str] = None
    Tantangan_Kekhawatiran: Optional[str] = None
    Fitur_Baru_Diinginkan: Optional[str] = None

# %%
SYNTHETIC_FEW_SHOT_PREFIX = "contoh survei tentang penggunaan alat pelacak oleh pelari:\n\n"
SYNTHETIC_FEW_SHOT_SUFFIX = """buatlah satu entri survei baru berdasarkan contoh berikut:
Subjek: {subject}
Detail tambahan: {extra}

Pastikan:
- jangan mengulangi nama responden yang sudah ada.
- gunakan format yang sama dengan contoh.
- Nama responden harus unik dan sesuai dengan jenis kelamin.
- Gunakan variasi dalam usia, asal, dan motivasi lari.

Output hanya berisi SATU entri dan tidak lebih.
"""

OPENAI_TEMPLATE = PromptTemplate(
    input_variables=["example"], 
    template="{example}"
    )

prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX,
    examples=examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
    input_variables=["subject", "extra"],
    example_prompt=OPENAI_TEMPLATE,
)

subject = "generasi muda yang aktif berlari dan menggunakan alat pelacak untuk meningkatkan performa mereka."
extra = "mereka tertarik dengan fitur baru yang dapat membantu mereka menetapkan target berdasarkan data yang dikumpulkan."

# %%
llm = ChatOpenAI(
  model = "qwen/qwen3-32b:free",
  temperature = 0.7,
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("QWEN_API_KEY"),
)
# Out:
# /var/folders/b9/5pxngp4x62q2qbmwnt1x80vr0000gn/T/ipykernel_1646/1305778179.py:1: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(

# %%
synthetic_data = []
for i in range(50):
    prompt = prompt_template.format(subject=subject, extra=extra)
    response = llm.predict(prompt)

    print(f"\n[iterazione {i+1}] Output di dati sintetici:\n{response}")

    fields = [field.strip() for field in response.strip().split(",")]
    entry_dict = {}
    for field in fields:
        if ": " in field:
            key, value = field.split(": ", 1)
            entry_dict[key.strip()] = value.strip()

    try:
        validated = SelfTrackingSurvey(**entry_dict)
        synthetic_data.append(validated.model_dump())
    except ValidationError as e:
        print(f"[ERROR] Validation error on entry {i+1}:\n{e}")
    
    time.sleep(1.5)
# Out:
# /var/folders/b9/5pxngp4x62q2qbmwnt1x80vr0000gn/T/ipykernel_1646/1871316959.py:4: LangChainDeprecationWarning: The method `BaseChatModel.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm.predict(prompt)
# [iterazione 1] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Dapat memantau progres latihan dengan akurat, Tantangan_Kekhawatiran: Kadang terlalu fokus pada target sehingga melupakan kenyamanan tubuh, Fitur_Baru_Diinginkan: Fitur penyesuaian target otomatis berdasarkan kondisi fisik harian
#
# [iterazione 2] Output di dati sintetici:
# Nama: Daniel, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi khusus pelari (RunKeeper), Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa tahu progres latihan dan tetap fokus pada target mingguan, Tantangan_Kekhawatiran: Kadang terlalu fokus pada angka, lupa nikmati proses lari, Fitur_Baru_Diinginkan: Analisis pola pelari dengan rekomendasi jarak/kecepatan optimal berdasarkan kondisi fisik hari itu.
#
# [iterazione 3] Output di dati sintetici:
# Nama: Rizal, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa analisis progres lari mingguan, Tantangan_Kekhawatiran: Overfitting data yang sulit dipahami, Fitur_Baru_Diinginkan: Fitur rekomendasi target otomatis berdasarkan performa harian.
#
# [iterazione 4] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target latihan berdasarkan data historis, Tantangan_Kekhawatiran: Data kadang tidak konsisten antar aplikasi, Fitur_Baru_Diinginkan: Fitur prediksi capaian berdasarkan tren data
#
# [iterazione 5] Output di dati sintetici:
# Nama: Rizal, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Meningkatkan performa lari melalui data akurasi, Tantangan_Kekhawatiran: Kurangnya baterai tahan lama, Fitur_Baru_Diinginkan: Fitur analisis pola lari untuk rekomendasi latihan personal.
#
# [iterazione 6] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target berdasarkan kemampuan harian, Tantangan_Kekhawatiran: Kurangnya informasi tentang nutrisi yang relevan, Fitur_Baru_Diinginkan: Fitur rekomendasi target jarak dan tempo otomatis berdasarkan histori latihan
#
# [iterazione 7] Output di dati sintetici:
# Nama: Indah, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan latihan berdasarkan data harian, Tantangan_Kekhawatiran: Kurang fleksibel dalam menyesuaikan tujuan, Fitur_Baru_Diinginkan: Fitur rekomendasi target berdasarkan progres pribadi
#
# [iterazione 8] Output di dati sintetici:
# Nama: Adrian, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memantau progres latihan secara akurat, Tantangan_Kekhawatiran: Notifikasi terlalu sering mengganggu fokus saat lari, Fitur_Baru_Diinginkan: Analisis pola lari otomatis untuk rekomendasi kecepatan/taktik
#
# [iterazione 9] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi khusus lari, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 4, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa memantau progres dan menyesuaikan latihan, Tantangan_Kekhawatiran: Data terlalu banyak dan membingungkan, Fitur_Baru_Diinginkan: Fitur rekomendasi target berlari dinamis berdasarkan histori data
#
# [iterazione 10] Output di dati sintetici:
# Nama: Dewi, Usia: 23, Jenis_Kelamin: Perempuan, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi pihak ketiga, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Monitoring recovery time setelah lari, Tantangan_Kekhawatiran: Data terlalu kompleks untuk dipahami, Fitur_Baru_Diinginkan: Rekomendasi target pribadi berdasarkan kondisi fisik dan cuaca.
#
# [iterazione 11] Output di dati sintetici:
# Nama: Fajar, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Meningkatkan akurasi pelatihan berdasarkan data biometrik, Tantangan_Kekhawatiran: Kesulitan memahami data untuk menetapkan target yang tepat, Fitur_Baru_Diinginkan: Analisis tujuan pelatihan otomatis berdasarkan pola pergerakan dan kebugaran.
#
# [iterazione 12] Output di dati sintetici:
# Nama: Sari, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi khusus berlari, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Motivasi berlari lebih efektif berdasarkan data pribadi, Tantangan_Kekhawatiran: Data terlalu kompleks untuk dipahami, Fitur_Baru_Diinginkan: Analisis pola lari untuk rekomendasi target personal.
#
# [iterazione 13] Output di dati sintetici:
# Nama: Sari, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Mudah mengatur jadwal latihan berdasarkan data, Tantangan_Kekhawatiran: Baterai cepat habis saat digunakan dalam jangka lama, Fitur_Baru_Diinginkan: Fitur rekomendasi target harian berdasarkan kondisi tubuh dan pola lari
#
# [iterazione 14] Output di dati sintetici:
# Nama: Daffa, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target berdasarkan progres harian, Tantangan_Kekhawatiran: Keprihatinan tentang privasi data kesehatan, Fitur_Baru_Diinginkan: Fitur rekomendasi rencana latihan otomatis
#
# [iterazione 15] Output di dati sintetici:
# Nama: Rifki, Usia: 23, Jenis_Kelamin: Laki-laki, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Dapat menyesuaikan target berdasarkan kemajuan harian, Tantangan_Kekhawatiran: Data terlalu banyak sehingga sering diabaikan, Fitur_Baru_Diinginkan: Fitur analisis pola latihan otomatis untuk rekomendasi target
#
# [iterazione 16] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Membantu merencanakan target harian secara terstruktur, Tantangan_Kekhawatiran: Kadang merasa kurang fleksibel karena target yang terlalu kaku, Fitur_Baru_Diinginkan: Fitur penyesuaian target otomatis berdasarkan kondisi fisik dan cuaca
#
# [iterazione 17] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target lari berdasarkan data harian, Tantangan_Kekhawatiran: Kadang merasa kewalahan dengan banyaknya data yang ditampilkan, Fitur_Baru_Diinginkan: Fitur penyesuaian target otomatis berdasarkan pola aktivitas dan kelelahan.
#
# [iterazione 18] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 4, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target berdasarkan kemampuan fisik saat ini, Tantangan_Kekhawatiran: Kadang merasa terlalu banyak data yang tidak dipahami, Fitur_Baru_Diinginkan: Fitur rekomendasi target personal yang otomatis
#
# [iterazione 19] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Dapat menyesuaikan target berdasarkan kemajuan harian, Tantangan_Kekhawatiran: Kurangnya variasi dalam rekomendasi latihan, Fitur_Baru_Diinginkan: Rekomendasi latihan dinamis berdasarkan data sebelumnya
#
# [iterazione 20] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Membantu mengatur waktu istirahat optimal, Tantangan_Kekhawatiran: Ketergantungan terhadap target harian, Fitur_Baru_Diinginkan: Rekomendasi target berdasarkan pola aktivitas bulanan
#
# [iterazione 21] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa tahu progres latihan secara akurat, Tantangan_Kekhawatiran: Tekanan untuk terus mencapai target ideal, Fitur_Baru_Diinginkan: Fitur rekomendasi target latihan berdasarkan kondisi tubuh
#
# [iterazione 22] Output di dati sintetici:
# Nama: Erik, Usia: 23, Jenis_Kelamin: Laki-laki, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Membantu menyesuaikan intensitas latihan berdasarkan data harian, Tantangan_Kekhawatiran: Kesulitan menafsirkan data untuk target yang lebih spesifik, Fitur_Baru_Diinginkan: Rencana latihan adaptif yang terus diperbarui sesuai progres pengguna
#
# [iterazione 23] Output di dati sintetici:
# Nama: Adit, Usia: 23, Jenis_Kelamin: Laki-laki, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Membantu menyesuaikan target berdasarkan kemajuan harian, Tantangan_Kekhawatiran: Kurangnya integrasi dengan sistem lain, Fitur_Baru_Diinginkan: Analisis data untuk rekomendasi latihan otomatis
#
# [iterazione 24] Output di dati sintetici:
# Nama: Maya, Usia: 23, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Mudah menyesuaikan target berdasarkan data harian, Tantangan_Kekhawatiran: Data terlalu teknis sehingga sulit diinterpretasi, Fitur_Baru_Diinginkan: Rekomendasi latihan pribadi berbasis AI
#
# [iterazione 25] Output di dati sintetici:
# Nama: Adi, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Meningkatkan akurasi dalam menetapkan target jarak dan kecepatan, Tantangan_Kekhawatiran: Kadang merasa terlalu memfokuskan pada target digital, Fitur_Baru_Diinginkan: Analisis pola lari untuk rekomendasi target yang lebih personal.
#
# [iterazione 26] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Meningkatkan akurasi latihan, Tantangan_Kekhawatiran: Kadang kesiangan karena alat perlu diisi daya, Fitur_Baru_Diinginkan: Analisis kinerja otomatis dan rekomendasi target mingguan
#
# [iterazione 27] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Dapat melacak perkembangan jarak lari dan durasi secara akurat, Tantangan_Kekhawatiran: Daya baterai alat cepat habis saat lari jarak jauh, Fitur_Baru_Diinginkan: Fitur rekomendasi rencana latihan personal berdasarkan performa sebelumnya
#
# [iterazione 28] Output di dati sintetici:
# Nama: Daffa, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target berdasarkan data harian, Tantangan_Kekhawatiran: Data terlalu banyak sehingga membingungkan, Fitur_Baru_Diinginkan: Fitur rekomendasi target otomatis berdasarkan kondisi tubuh
#
# [iterazione 29] Output di dati sintetici:
# Nama: Daffa, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real-Time_Data: 4, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Membantu menyesuaikan intensitas latihan sesuai kemampuan tubuh, Tantangan_Kekhawatiran: Kurangnya fitur personalisasi untuk target berlari, Fitur_Baru_Diinginkan: Fitur analisis data latihan untuk rekomendasi target berlari
# [ERROR] Validation error on entry 29:
# 1 validation error for SelfTrackingSurvey
# Motivasi_Real_Time_Data
#   Field required [type=missing, input_value={'Nama': 'Daffa', 'Usia':...mendasi target berlari'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# [iterazione 30] Output di dati sintetici:
# Nama: Siti, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi lari khusus, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memantau progres latihan secara akurat, Tantangan_Kekhawatiran: Data terlalu kompleks untuk dipahami, Fitur_Baru_Diinginkan: Analisis performa dengan AI untuk rekomendasi target yang lebih personal
#
# [iterazione 31] Output di dati sintetici:
# Nama: Aisyah, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Membantu menyesuaikan intensitas latihan secara ilmiah, Tantangan_Kekhawatiran: Kekurangan baterai saat latihan jarak jauh, Fitur_Baru_Diinginkan: Analisis data latihan untuk rekomendasi target harian otomatis
#
# [iterazione 32] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menetapkan target berdasarkan pola latihan sebelumnya, Tantangan_Kekhawatiran: Kadang merasa terlalu fokus pada angka, Fitur_Baru_Diinginkan: Fitur prediksi jarak lari optimal berdasarkan data kebugaran.
#
# [iterazione 33] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 1, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa monitor progres latihan dan kecepatan, Tantangan_Kekhawatiran: Data terlalu banyak sehingga susah fokus, Fitur_Baru_Diinginkan: Fitur penyesuaian target otomatis berdasarkan ketinggian medan dan cuaca
#
# [iterazione 34] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Aplikasi smartphone, GPS, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Meningkatkan akurasi latihan dengan data jarak dan kecepatan, Tantangan_Kekhawatiran: Sulit memahami data yang terlalu banyak, Fitur_Baru_Diinginkan: Rekomendasi target otomatis berdasarkan kemampuan fisik
#
# [iterazione 35] Output di dati sintetici:
# Nama: Sari, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, beberapa kali seminggu, Jenis_Alat_Pelacak: Aplikasi smartphone, Aksesori pelacakan jarak, Motivasi_Real-Time_Data: 4, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 4, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memantau progres lari secara akurat, Tantangan_Kekhawatiran: Data terkadang membingungkan, Fitur_Baru_Diinginkan: Analisis pola lari untuk rekomendasi target otomatis
# [ERROR] Validation error on entry 35:
# 1 validation error for SelfTrackingSurvey
# Motivasi_Real_Time_Data
#   Field required [type=missing, input_value={'Nama': 'Sari', 'Usia': ...endasi target otomatis'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# [iterazione 36] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real-Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Dapat mengoptimalkan latihan berdasarkan data harian, Tantangan_Kekhawatiran: Kadang sulit memahami data yang kompleks, Fitur_Baru_Diinginkan: Fitur AI yang merekomendasikan target latihan otomatis berdasarkan performa sebelumnya.
# [ERROR] Validation error on entry 36:
# 1 validation error for SelfTrackingSurvey
# Motivasi_Real_Time_Data
#   Field required [type=missing, input_value={'Nama': 'Dinda', 'Usia':...n performa sebelumnya.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# [iterazione 37] Output di dati sintetici:
# Nama: Raihan, Usia: 26, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memahami progres latihan secara akurat, Tantangan_Kekhawatiran: Kurangnya pemahaman tentang bagaimana mengoptimalkan data untuk target yang realistis, Fitur_Baru_Diinginkan: Fitur rekomendasi target otomatis berdasarkan performa sebelumnya
#
# [iterazione 38] Output di dati sintetici:
# Nama: Daffa, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch (Garmin), Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 2, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Pantau progres lari secara akurat, Tantangan_Kekhawatiran: Data terlalu detail justru membingungkan, Fitur_Baru_Diinginkan: Fitur rekomendasi target harian berdasarkan performa mingguan
#
# [iterazione 39] Output di dati sintetici:
# Nama: Sari, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan latihan berdasarkan data yang akurat, Tantangan_Kekhawatiran: Kadang kurang memahami data yang kompleks, Fitur_Baru_Diinginkan: Fitur rekomendasi target mingguan berdasarkan data historis
#
# [iterazione 40] Output di dati sintetici:
# Nama: Sari, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Jakarta, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi pihak ketiga (Strava), Motivasi_Real-Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memantau progres latihan secara akurat, Tantangan_Kekhawatiran: Kadang lupa mengisi daya alat pelacak secara teratur, Fitur_Baru_Diinginkan: Rekomendasi jarak lari berdasarkan data kebugaran harian
# [ERROR] Validation error on entry 40:
# 1 validation error for SelfTrackingSurvey
# Motivasi_Real_Time_Data
#   Field required [type=missing, input_value={'Nama': 'Sari', 'Usia': ... data kebugaran harian'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# [iterazione 41] Output di dati sintetici:
# Nama: Adi, Usia: 24, Jenis_Kelamin: Laki-laki, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target latihan otomatis berdasarkan kemajuan mingguan, Tantangan_Kekhawatiran: Baterai alat cepat habis saat lari jarak jauh, Fitur_Baru_Diinginkan: Fitur rekomendasi target latihan adaptif berdasarkan pola aktivitas harian.
#
# [iterazione 42] Output di dati sintetici:
# Nama: Siti, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Denpasar, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Dapat menetapkan target lari berdasarkan data yang akurat, Tantangan_Kekhawatiran: Kesulitan menyesuaikan target dengan jadwal harian yang dinamis, Fitur_Baru_Diinginkan: Fitur penyesuaian target lari otomatis berdasarkan kondisi fisik dan cuaca
#
# [iterazione 43] Output di dati sintetici:
# Nama: Dandi, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memantau progres dan menghindari cedera, Tantangan_Kekhawatiran: Data terlalu banyak sehingga membingungkan, Fitur_Baru_Diinginkan: Fitur rekomendasi latihan personal berdasarkan data historis.
#
# [iterazione 44] Output di dati sintetici:
# Nama: Daffa, Usia: 26, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Fitness tracker, Motivasi_Real-Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Memantau progres latihan secara akurat, Tantangan_Kekhawatiran: Kadang lupa menarik data dari aplikasi karena kurangnya waktu, Fitur_Baru_Diinginkan: Fitur rekomendasi rutin latihan otomatis berdasarkan performa harian.
# [ERROR] Validation error on entry 44:
# 1 validation error for SelfTrackingSurvey
# Motivasi_Real_Time_Data
#   Field required [type=missing, input_value={'Nama': 'Daffa', 'Usia':...arkan performa harian.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# [iterazione 45] Output di dati sintetici:
# Nama: Dinda, Usia: 24, Jenis_Kelamin: Perempuan, Asal: Semarang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Fitness tracker, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 4, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa mengatur jadwal latihan berdasarkan data, Tantangan_Kekhawatiran: Data terlalu banyak sehingga sulit diproses, Fitur_Baru_Diinginkan: Rekomendasi target berdasarkan kinerja mingguan
#
# [iterazione 46] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target berdasarkan progres mingguan, Tantangan_Kekhawatiran: Kadang bingung memahami data yang kompleks, Fitur_Baru_Diinginkan: Fitur rekomendasi target otomatis berdasarkan pola latihan
#
# [iterazione 47] Output di dati sintetici:
# Nama: Felix, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Palembang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi khusus lari, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 4, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa menyesuaikan target berdasarkan progres harian, Tantangan_Kekhawatiran: Terlalu banyak data sehingga sulit menetapkan fokus utama, Fitur_Baru_Diinginkan: Fitur rekomendasi target otomatis berdasarkan histori performa
#
# [iterazione 48] Output di dati sintetici:
# Nama: Andra, Usia: 21, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 4, Bandingkan_di_Media_Sosial: 3, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 2, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Mudah menyesuaikan target berdasarkan performa harian, Tantangan_Kekhawatiran: Kurang akurat saat pelari di area dengan banyak pohon, Fitur_Baru_Diinginkan: Fitur rekomendasi target otomatis berdasarkan histori data.
#
# [iterazione 49] Output di dati sintetici:
# Nama: Irfan, Usia: 23, Jenis_Kelamin: Laki-laki, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Fitness tracker, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 4, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa evaluasi performa lari secara akurat dan fleksibel, Tantangan_Kekhawatiran: Tidak suka data yang terlalu detail membuat analisis terasa rumit, Fitur_Baru_Diinginkan: Fitur AI yang analisis data harian untuk menetapkan target jarak/kecepatan otomatis.
#
# [iterazione 50] Output di dati sintetici:
# Nama: Dinda, Usia: 21, Jenis_Kelamin: Perempuan, Asal: Malang, Penggunaan_Alat_Pelacak: Ya, setiap hari, Jenis_Alat_Pelacak: Smartwatch, Aplikasi smartphone, Motivasi_Real_Time_Data: 5, Bandingkan_di_Media_Sosial: 4, Bantu_Konsistensi: 5, Rasa_Bersalah_Jika_Tidak_Capai_Target: 3, Meningkatkan_Pola_Hidup: 5, Menetapkan_Target_dari_Data: 5, Manfaat_Terbesar: Bisa melacak progres latihan secara detail, Tantangan_Kekhawatiran: Data terlalu banyak, susah fokus pada yang penting, Fitur_Baru_Diinginkan: Rekomendasi tipe latihan otomatis berdasarkan kondisi tubuh.

# %%
df = pd.DataFrame(synthetic_data)
df
# Out:
#       Nama  Usia Jenis_Kelamin       Asal Penggunaan_Alat_Pelacak  \
# 0    Dinda    21     Perempuan   Semarang                      Ya
# 1   Daniel    21     Laki-laki  Palembang                      Ya
# 2    Rizal    21     Laki-laki    Jakarta                      Ya
# 3    Dinda    21     Perempuan   Denpasar                      Ya
# 4    Rizal    21     Laki-laki    Jakarta                      Ya
# 5    Dinda    21     Perempuan   Semarang                      Ya
# 6    Indah    21     Perempuan   Semarang                      Ya
# 7   Adrian    21     Laki-laki    Jakarta                      Ya
# 8    Dinda    21     Perempuan   Denpasar                      Ya
# 9     Dewi    23     Perempuan  Palembang                      Ya
# 10   Fajar    21     Laki-laki     Malang                      Ya
# 11    Sari    21     Perempuan     Malang                      Ya
# 12    Sari    21     Perempuan   Semarang                      Ya
# 13   Daffa    21     Laki-laki   Denpasar                      Ya
# 14   Rifki    23     Laki-laki  Palembang                      Ya
# 15   Dinda    21     Perempuan   Semarang                      Ya
# 16   Dinda    21     Perempuan  Palembang                      Ya
# 17   Dinda    21     Perempuan    Jakarta                      Ya
# 18   Dinda    21     Perempuan   Denpasar                      Ya
# 19   Dinda    21     Perempuan     Malang                      Ya
# 20   Dinda    21     Perempuan  Palembang                      Ya
# 21    Erik    23     Laki-laki   Semarang                      Ya
# 22    Adit    23     Laki-laki    Jakarta                      Ya
# 23    Maya    23     Perempuan     Malang                      Ya
# 24     Adi    21     Laki-laki     Malang                      Ya
# 25   Dinda    21     Perempuan   Denpasar                      Ya
# 26   Dinda    21     Perempuan   Semarang                      Ya
# 27   Daffa    21     Laki-laki   Denpasar                      Ya
# 28    Siti    21     Perempuan   Denpasar                      Ya
# 29  Aisyah    21     Perempuan   Semarang                      Ya
# 30   Dinda    21     Perempuan     Malang                      Ya
# 31   Dinda    21     Perempuan     Malang                      Ya
# 32   Dinda    21     Perempuan     Malang                      Ya
# 33  Raihan    26     Laki-laki     Malang                      Ya
# 34   Daffa    21     Laki-laki   Semarang                      Ya
# 35    Sari    21     Perempuan   Semarang                      Ya
# 36     Adi    24     Laki-laki   Semarang                      Ya
# 37    Siti    21     Perempuan   Denpasar                      Ya
# 38   Dandi    21     Laki-laki     Malang                      Ya
# 39   Dinda    24     Perempuan   Semarang                      Ya
# 40   Dinda    21     Perempuan  Palembang                      Ya
# 41   Felix    21     Laki-laki  Palembang                      Ya
# 42   Andra    21     Laki-laki     Malang                      Ya
# 43   Irfan    23     Laki-laki     Malang                      Ya
# 44   Dinda    21     Perempuan     Malang                      Ya
#
#      Jenis_Alat_Pelacak  Motivasi_Real_Time_Data  Bandingkan_di_Media_Sosial  \
# 0            Smartwatch                        5                           4
# 1            Smartwatch                        5                           3
# 2            Smartwatch                        4                           2
# 3            Smartwatch                        5                           4
# 4            Smartwatch                        5                           2
# 5       Fitness tracker                        5                           4
# 6            Smartwatch                        4                           4
# 7            Smartwatch                        5                           4
# 8            Smartwatch                        5                           3
# 9            Smartwatch                        4                           3
# 10           Smartwatch                        5                           2
# 11           Smartwatch                        5                           2
# 12      Fitness tracker                        5                           4
# 13           Smartwatch                        5                           4
# 14           Smartwatch                        5                           4
# 15           Smartwatch                        5                           4
# 16      Fitness tracker                        4                           4
# 17           Smartwatch                        4                           3
# 18           Smartwatch                        5                           2
# 19           Smartwatch                        5                           4
# 20      Fitness tracker                        5                           3
# 21           Smartwatch                        5                           4
# 22           Smartwatch                        5                           2
# 23      Fitness tracker                        4                           3
# 24           Smartwatch                        5                           4
# 25           Smartwatch                        5                           4
# 26      Fitness tracker                        5                           4
# 27           Smartwatch                        4                           3
# 28           Smartwatch                        5                           4
# 29           Smartwatch                        5                           4
# 30      Fitness tracker                        5                           3
# 31      Fitness tracker                        5                           1
# 32  Aplikasi smartphone                        5                           4
# 33           Smartwatch                        5                           4
# 34  Smartwatch (Garmin)                        5                           2
# 35           Smartwatch                        5                           4
# 36           Smartwatch                        5                           4
# 37           Smartwatch                        5                           3
# 38           Smartwatch                        5                           4
# 39      Fitness tracker                        5                           3
# 40           Smartwatch                        5                           4
# 41           Smartwatch                        5                           4
# 42           Smartwatch                        4                           3
# 43           Smartwatch                        5                           4
# 44           Smartwatch                        5                           4
#
#     Bantu_Konsistensi  Rasa_Bersalah_Jika_Tidak_Capai_Target  \
# 0                   5                                      3
# 1                   5                                      4
# 2                   5                                      3
# 3                   5                                      3
# 4                   5                                      3
# 5                   5                                      4
# 6                   5                                      4
# 7                   5                                      3
# 8                   4                                      3
# 9                   5                                      4
# 10                  5                                      3
# 11                  5                                      3
# 12                  5                                      4
# 13                  5                                      3
# 14                  5                                      4
# 15                  5                                      4
# 16                  5                                      4
# 17                  4                                      2
# 18                  5                                      3
# 19                  5                                      4
# 20                  5                                      4
# 21                  5                                      3
# 22                  5                                      4
# 23                  5                                      3
# 24                  5                                      3
# 25                  5                                      2
# 26                  5                                      4
# 27                  5                                      2
# 28                  5                                      2
# 29                  5                                      3
# 30                  5                                      4
# 31                  5                                      4
# 32                  5                                      3
# 33                  5                                      4
# 34                  5                                      3
# 35                  5                                      4
# 36                  5                                      3
# 37                  5                                      4
# 38                  5                                      3
# 39                  4                                      2
# 40                  5                                      4
# 41                  5                                      4
# 42                  5                                      2
# 43                  5                                      3
# 44                  5                                      3
#
#     Meningkatkan_Pola_Hidup  Menetapkan_Target_dari_Data  \
# 0                         5                            5
# 1                         5                            5
# 2                         4                            5
# 3                         5                            5
# 4                         4                            5
# 5                         5                            5
# 6                         5                            5
# 7                         5                            5
# 8                         5                            5
# 9                         5                            5
# 10                        5                            5
# 11                        5                            5
# 12                        5                            5
# 13                        5                            5
# 14                        5                            5
# 15                        5                            5
# 16                        5                            5
# 17                        4                            5
# 18                        5                            5
# 19                        5                            5
# 20                        5                            5
# 21                        4                            5
# 22                        4                            5
# 23                        4                            5
# 24                        4                            5
# 25                        5                            5
# 26                        5                            5
# 27                        4                            5
# 28                        5                            5
# 29                        5                            5
# 30                        5                            5
# 31                        5                            5
# 32                        4                            5
# 33                        5                            5
# 34                        5                            5
# 35                        5                            5
# 36                        5                            5
# 37                        5                            5
# 38                        5                            5
# 39                        4                            5
# 40                        5                            5
# 41                        5                            5
# 42                        4                            5
# 43                        4                            5
# 44                        5                            5
#
#                                      Manfaat_Terbesar  \
# 0        Dapat memantau progres latihan dengan akurat
# 1   Bisa tahu progres latihan dan tetap fokus pada...
# 2                 Bisa analisis progres lari mingguan
# 3   Bisa menyesuaikan target latihan berdasarkan d...
# 4     Meningkatkan performa lari melalui data akurasi
# 5   Bisa menyesuaikan target berdasarkan kemampuan...
# 6   Bisa menyesuaikan latihan berdasarkan data harian
# 7              Memantau progres latihan secara akurat
# 8      Bisa memantau progres dan menyesuaikan latihan
# 9               Monitoring recovery time setelah lari
# 10  Meningkatkan akurasi pelatihan berdasarkan dat...
# 11  Motivasi berlari lebih efektif berdasarkan dat...
# 12     Mudah mengatur jadwal latihan berdasarkan data
# 13  Bisa menyesuaikan target berdasarkan progres h...
# 14  Dapat menyesuaikan target berdasarkan kemajuan...
# 15  Membantu merencanakan target harian secara ter...
# 16  Bisa menyesuaikan target lari berdasarkan data...
# 17  Bisa menyesuaikan target berdasarkan kemampuan...
# 18  Dapat menyesuaikan target berdasarkan kemajuan...
# 19          Membantu mengatur waktu istirahat optimal
# 20            Bisa tahu progres latihan secara akurat
# 21  Membantu menyesuaikan intensitas latihan berda...
# 22  Membantu menyesuaikan target berdasarkan kemaj...
# 23  Mudah menyesuaikan target berdasarkan data harian
# 24  Meningkatkan akurasi dalam menetapkan target j...
# 25                       Meningkatkan akurasi latihan
# 26  Dapat melacak perkembangan jarak lari dan dura...
# 27   Bisa menyesuaikan target berdasarkan data harian
# 28             Memantau progres latihan secara akurat
# 29  Membantu menyesuaikan intensitas latihan secar...
# 30  Bisa menetapkan target berdasarkan pola latiha...
# 31         Bisa monitor progres latihan dan kecepatan
# 32  Meningkatkan akurasi latihan dengan data jarak...
# 33             Memahami progres latihan secara akurat
# 34                  Pantau progres lari secara akurat
# 35  Bisa menyesuaikan latihan berdasarkan data yan...
# 36  Bisa menyesuaikan target latihan otomatis berd...
# 37  Dapat menetapkan target lari berdasarkan data ...
# 38            Memantau progres dan menghindari cedera
# 39      Bisa mengatur jadwal latihan berdasarkan data
# 40  Bisa menyesuaikan target berdasarkan progres m...
# 41  Bisa menyesuaikan target berdasarkan progres h...
# 42  Mudah menyesuaikan target berdasarkan performa...
# 43  Bisa evaluasi performa lari secara akurat dan ...
# 44         Bisa melacak progres latihan secara detail
#
#                                Tantangan_Kekhawatiran  \
# 0   Kadang terlalu fokus pada target sehingga melu...
# 1                     Kadang terlalu fokus pada angka
# 2                Overfitting data yang sulit dipahami
# 3          Data kadang tidak konsisten antar aplikasi
# 4                        Kurangnya baterai tahan lama
# 5    Kurangnya informasi tentang nutrisi yang relevan
# 6          Kurang fleksibel dalam menyesuaikan tujuan
# 7   Notifikasi terlalu sering mengganggu fokus saa...
# 8               Data terlalu banyak dan membingungkan
# 9                Data terlalu kompleks untuk dipahami
# 10  Kesulitan memahami data untuk menetapkan targe...
# 11               Data terlalu kompleks untuk dipahami
# 12  Baterai cepat habis saat digunakan dalam jangk...
# 13        Keprihatinan tentang privasi data kesehatan
# 14      Data terlalu banyak sehingga sering diabaikan
# 15  Kadang merasa kurang fleksibel karena target y...
# 16  Kadang merasa kewalahan dengan banyaknya data ...
# 17  Kadang merasa terlalu banyak data yang tidak d...
# 18        Kurangnya variasi dalam rekomendasi latihan
# 19              Ketergantungan terhadap target harian
# 20          Tekanan untuk terus mencapai target ideal
# 21  Kesulitan menafsirkan data untuk target yang l...
# 22             Kurangnya integrasi dengan sistem lain
# 23  Data terlalu teknis sehingga sulit diinterpretasi
# 24  Kadang merasa terlalu memfokuskan pada target ...
# 25      Kadang kesiangan karena alat perlu diisi daya
# 26  Daya baterai alat cepat habis saat lari jarak ...
# 27         Data terlalu banyak sehingga membingungkan
# 28               Data terlalu kompleks untuk dipahami
# 29         Kekurangan baterai saat latihan jarak jauh
# 30             Kadang merasa terlalu fokus pada angka
# 31           Data terlalu banyak sehingga susah fokus
# 32            Sulit memahami data yang terlalu banyak
# 33  Kurangnya pemahaman tentang bagaimana mengopti...
# 34           Data terlalu detail justru membingungkan
# 35          Kadang kurang memahami data yang kompleks
# 36      Baterai alat cepat habis saat lari jarak jauh
# 37  Kesulitan menyesuaikan target dengan jadwal ha...
# 38         Data terlalu banyak sehingga membingungkan
# 39        Data terlalu banyak sehingga sulit diproses
# 40         Kadang bingung memahami data yang kompleks
# 41  Terlalu banyak data sehingga sulit menetapkan ...
# 42  Kurang akurat saat pelari di area dengan banya...
# 43  Tidak suka data yang terlalu detail membuat an...
# 44                                Data terlalu banyak
#
#                                 Fitur_Baru_Diinginkan
# 0   Fitur penyesuaian target otomatis berdasarkan ...
# 1   Analisis pola pelari dengan rekomendasi jarak/...
# 2   Fitur rekomendasi target otomatis berdasarkan ...
# 3        Fitur prediksi capaian berdasarkan tren data
# 4   Fitur analisis pola lari untuk rekomendasi lat...
# 5   Fitur rekomendasi target jarak dan tempo otoma...
# 6   Fitur rekomendasi target berdasarkan progres p...
# 7   Analisis pola lari otomatis untuk rekomendasi ...
# 8   Fitur rekomendasi target berlari dinamis berda...
# 9   Rekomendasi target pribadi berdasarkan kondisi...
# 10  Analisis tujuan pelatihan otomatis berdasarkan...
# 11  Analisis pola lari untuk rekomendasi target pe...
# 12  Fitur rekomendasi target harian berdasarkan ko...
# 13         Fitur rekomendasi rencana latihan otomatis
# 14  Fitur analisis pola latihan otomatis untuk rek...
# 15  Fitur penyesuaian target otomatis berdasarkan ...
# 16  Fitur penyesuaian target otomatis berdasarkan ...
# 17    Fitur rekomendasi target personal yang otomatis
# 18  Rekomendasi latihan dinamis berdasarkan data s...
# 19  Rekomendasi target berdasarkan pola aktivitas ...
# 20  Fitur rekomendasi target latihan berdasarkan k...
# 21  Rencana latihan adaptif yang terus diperbarui ...
# 22   Analisis data untuk rekomendasi latihan otomatis
# 23            Rekomendasi latihan pribadi berbasis AI
# 24  Analisis pola lari untuk rekomendasi target ya...
# 25  Analisis kinerja otomatis dan rekomendasi targ...
# 26  Fitur rekomendasi rencana latihan personal ber...
# 27  Fitur rekomendasi target otomatis berdasarkan ...
# 28  Analisis performa dengan AI untuk rekomendasi ...
# 29  Analisis data latihan untuk rekomendasi target...
# 30  Fitur prediksi jarak lari optimal berdasarkan ...
# 31  Fitur penyesuaian target otomatis berdasarkan ...
# 32  Rekomendasi target otomatis berdasarkan kemamp...
# 33  Fitur rekomendasi target otomatis berdasarkan ...
# 34  Fitur rekomendasi target harian berdasarkan pe...
# 35  Fitur rekomendasi target mingguan berdasarkan ...
# 36  Fitur rekomendasi target latihan adaptif berda...
# 37  Fitur penyesuaian target lari otomatis berdasa...
# 38  Fitur rekomendasi latihan personal berdasarkan...
# 39    Rekomendasi target berdasarkan kinerja mingguan
# 40  Fitur rekomendasi target otomatis berdasarkan ...
# 41  Fitur rekomendasi target otomatis berdasarkan ...
# 42  Fitur rekomendasi target otomatis berdasarkan ...
# 43  Fitur AI yang analisis data harian untuk menet...
# 44  Rekomendasi tipe latihan otomatis berdasarkan ...
